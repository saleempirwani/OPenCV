# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../image/puppy1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# img

# %%
img1 = cv2.imread('../image/puppy1.jpg')
type(img1)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (812, 1023, 3)

# %%
plt.imshow(img)

# %%
# matplotlib → RGB
# OpenCv → BGR

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../image/puppy1.jpg', cv2.IMREAD_GRAYSCALE) # cv2.IMREAD_GRAYSCALE = 0

# %%
img_gray.shape
# Out:
# (812, 1023)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 243

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
fix_img.shape
# Out:
# (812, 1023, 3)

# %%
new_img = cv2.resize(fix_img, (500, 500))

# %%
plt.imshow(new_img)

# %%
wid_ratio = 0.5
hei_ratio = 0.5

# %%
new_img = cv2.resize(fix_img, (0, 0), fix_img, wid_ratio, hei_ratio)

# %%
new_img.shape
# Out:
# (406, 512, 3)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img, 0)
plt.imshow(new_img)

# %%
cv2.imwrite('../image/sample.jpg', fix_img)
# Out:
# True

# %%
plt.imshow(fix_img)

# %%
fig = plt.figure(figsize=(2, 4)) # ek khali figure created kregaa...
ax = fig.add_subplot(111) # usme ek single subplot dale gaa...
ax.imshow(fix_img) # phir jo image show krni hai wo kro...
