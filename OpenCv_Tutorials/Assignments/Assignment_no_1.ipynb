# %%
import numpy as np

# %%
np.ones((5,5)) * 10
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
np.random.seed(101)
arr = np.random.randint(low=0, high=100, size=(5,5))

# %%
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %%
from PIL import Image

# %%
pic = Image.open('image/puppy1.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1023x812 at 0xBB46C77630>

# %%
pic_blue = np.asarray(pic)

# %%
pic_blue = pic_.copy()

# %%
pic_blue.shape
# Out:
# (812, 1023, 3)

# %%
# R=0; G=1; B=2;
pic_blue[:,:,0] =0
pic_blue[:,:,1] = 1

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(pic_blue)
