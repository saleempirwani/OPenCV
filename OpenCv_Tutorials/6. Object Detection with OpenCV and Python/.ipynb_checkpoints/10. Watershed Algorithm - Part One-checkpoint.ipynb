# %%
import cv2
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def disp(img, cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap)

# %%
sep_coin = cv2.imread('../image/pennies.jpg')

# %%
disp(sep_coin)

# %%
# Median Blur
# GrayScale
# Binary Threshold
# Find Contours

# %%
sep_blur = cv2.medianBlur(sep_coin, 25)
disp(sep_blur)

# %%
sep_gray = cv2.cvtColor(sep_blur, cv2.COLOR_BGR2GRAY)
disp(sep_gray)

# %%
ret, sep_th = cv2.threshold(sep_gray, 200, 255, cv2.THRESH_BINARY_INV)
disp(sep_th)

# %%
img, contours, hierachy = cv2.findContours(sep_th.copy(), cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
sep_coin_copy = sep_coin.copy()

for i in range(len(contours)):
    if hierachy[0][i][3] == -1:
        cv2.drawContours(sep_coin_copy, contours, i, (255,0,0), 10)
        
disp(sep_coin_copy)
